# %% [markdown]
# Answers for Week 1
#
# * Name: Jinne Alberda
# * Username: jwalberda
# * Student s-number: S6378439
# * Group (AS1, etc.): AS4

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![tux.png](attachment:5e1c8938-4023-4476-bdf8-c1eb35ff6752.png)

# %%
fact = 1 # factorial of 6 the long way
fact *= 6
fact *= 5
fact *= 4
fact *= 3
fact *= 2
fact *= 1
print(fact)
# Out:
# 720

# %%
h = 6.626e-34
c = 299792458
l = 2.42e28
e = ((h*c)/l)
print(e)
# Out:
# 8.208367052512397e-54

# %%
m = 7.342e22
e = 5.9722e24
g = 6.67e-11
d = 385e6
f = g*m*e/(d*d)
print(f)
# Out:
# 1.973118180522854e+20

# %% [markdown]
# ![Screenshot from 2026-02-10 14-07-47.png](attachment:52f13281-8d91-4604-801a-f4eddfd14fd9.png) the dot rep

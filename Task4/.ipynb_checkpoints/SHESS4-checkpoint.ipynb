# %% [markdown]
# 4.1

# %%
x = [1,2,3,10]
y = [10, 20, 30, 40]

z = [x+y  for x, y in zip(x, y)]

def fun(x, y):
    return x + y

pami = map(fun, x, y)

print(z)
print(list(pami))
# Out:
# [11, 22, 33, 50]
# [11, 22, 33, 50]

# %% [markdown]
# 4.3

# %%
import numpy as np

my = input("r, p, s for rock paper or scissors (lowercase)")
com = (np.random.rand()*3)//1 # generates random pick

cem = 9

if my == 'r': # assigns numer to my pick
    cem = 0
elif my == 'p':
    cem = 1
elif my == 's':
    cem = 2
    

if ((cem == 0 and com == 2) or (cem == 1 and com == 0) or (cem == 2 and com == 1)): # checks for winning
    print("You win!")
elif ((cem == 2 and com == 0)or (cem == 0 and com == 1) or (cem == 1 and com == 2)):
    print("You lose!")
else :
    print("Draw")
# Out:
# r, p, s for rock paper or scissors (lowercase)r
# You lose!

# %% [markdown]
# 4.4

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

pepl = np.random.normal(185, 8, 100000)

plt.hist(pepl, 40)

mien = np.mean(pepl)
sand = np.std(pepl)
print(sand)
plt.axvline(x = mien, color = 'r', label = 'Mean')
plt.axvspan(mien-sand, mien+sand, color = "g", alpha=0.4, label='Standard Deviation')
plt.legend()
# Out:
# 7.99111333295534

# %%
#4.15
import numpy as np
def func_filter(func,seq):
    res = []
    myseq = []
    if type(seq) == int:
        myseq.append(seq)
    else: 
        myseq = seq
    for i in myseq:
        if i > 0:
            res.append(i)
    return func(res)

sq = np.array([-100, -10, 0, 10, 100])
result = func_filter(np.log10, sq)
print("Result log10:", result)

sq = 100
myfnuc = func_filter(np.log10, sq)
print("Result log10:", myfnuc)
# Out:
# Result log10: [1. 2.]
# Result log10: [2.]

# %%
#4.16
from astropy.cosmology import Planck18
import numpy as np
import scipy

H0 = Planck18.H0.value
Om0 = Planck18.Om0
Ode0 = Planck18.Ode0

def aicz(zed):
    rut = Om0*((1+zed)**3)+Ode0
    return (H0*np.sqrt(Om0*((1+zed)**3)+Ode0))

def inter(grate):
    return 1/((1+grate)
              *(H0*np.sqrt(Om0*((1+grate)**3)+Ode0)))

def tl(zed):
    tim, _ = scipy.integrate.quad(inter, 0, zed)
    return tim

print(tl(2))
# Out:
# 0.010765276277273951

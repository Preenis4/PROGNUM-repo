# %% [markdown]
# $$\begin{gather}\displaystyle\sum_{k=0}^\infty \frac{1}{4k^2-1}=\frac{1}{2} \\
# \int_0^\pi e^{ix}dx=2i\end{gather}$$

# %%
from math import atan2, degrees
x= float(input("x="))
y=float(input("y="))
res = atan2(x,y)
if res>1:
    print("q1")
elif res>1:
    print("q2")
elif res<0:
    print("q3")
elif res<-1:
    print("q3")
print(res)
# the atan2 can specify the quadrant
# Out:
# x= -1
# y= -1
# q3
# -2.356194490192345

# %%
x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
x.append(0.51)
x.pop(3)
print(x[6])
# 1.46 is at index 1
s = x[2:7:2]
print(s)
sum =0
for i in s:
    sum+=i
print(sum)
# Out:
# 1.97
# [1.41, 0.98, 1.97]
# 4.359999999999999

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
night1 = set(night1)
night2 = set(night2)
inters = set.intersection(night1, night2)
interlist = list(inters)
if 5 in inters:
    print("5 is in set intersection")
else:
    print("5 is not in set intersection")
if 5 in night1:
    print("5 is in set night1")
# Out:
# 5 is in set night1

# %%
import numpy as np
l = np.random.normal(0, 1.4, 100000)
s = np.std(l, ddof=1)
print(s)
# Out:
# 1.404256255262135

# %%
a = 1
b = 1
for i in range(100):
    a, b = b, a+b
print(a)
# Out:
# 573147844013817084101

# %% [markdown]
# q23 ![Screenshot from 2026-02-17 14-11-35.png](attachment:9f09b59f-5560-4ee9-a433-45c5b0107ba1.png)

# %%
masses = [1.9891e+30, 1.8986e+27, 
          5.6846e+26, 1.0243e+26, 8.6810e+25,
          5.9736e+24, 4.8685e+24, 6.4185e+23, 
          3.3022e+23, 7.349e+22, 1.25e22]
pit= []
for i in masses:
    print(i)
    if i <= (7.349e+22):
        continue
    pit.append(i)

print(pit)
pot = masses[6:11]
print(pot)

avg = (sum(pot)/len(pot))
print(avg)
# Out:
# 1.9891e+30
# 1.8986e+27
# 5.6846e+26
# 1.0243e+26
# 8.681e+25
# 5.9736e+24
# 4.8685e+24
# 6.4185e+23
# 3.3022e+23
# 7.349e+22
# 1.25e+22
# [1.9891e+30, 1.8986e+27, 5.6846e+26, 1.0243e+26, 8.681e+25, 5.9736e+24, 4.8685e+24, 6.4185e+23, 3.3022e+23]
# [4.8685e+24, 6.4185e+23, 3.3022e+23, 7.349e+22, 1.25e+22]
# 1.1853119999999999e+24

# %%
import math
from scipy.constants import G

def v_esc(mass, radius):
    res = math.sqrt((2*G*mass)/radius)
    return res//1

masses = [1.9891e+30, 1.8986e+27, 5.6846e+26, 
          1.0243e+26, 8.6810e+25, 5.9736e+24, 
          4.8685e+24, 6.4185e+23, 3.3022e+23, 
          7.349e+22, 1.25e22]
radii  = [696340, 71492, 60268, 24764, 
          25559, 6378.1, 6051.8, 3396.2, 
          2439.7, 1738.1, 1195]
names  = ['Sun', 'Jupiter', 'Saturn', 'Neptune', 
          'Uranus', 'Earth', 'Venus', 'Mars', 
          'Mercury', 'Moon', 'Pluto']

for m,r,n in zip(masses,radii,names):
    print(f"V_esc = {v_esc(m, r)}. Mass = {m:.2f}. Name: {n}.")
# Out:
# V_esc = 19526998.0. Mass = 1989099999999999887809347321856.00. Name: Sun.
# V_esc = 1882807.0. Mass = 1898599999999999942269599744.00. Name: Jupiter.
# V_esc = 1122081.0. Mass = 568460000000000028999417856.00. Name: Saturn.
# V_esc = 743055.0. Mass = 102430000000000008208252928.00. Name: Neptune.
# V_esc = 673334.0. Mass = 86810000000000006505365504.00. Name: Uranus.
# V_esc = 353582.0. Mass = 5973599999999999505072128.00. Name: Earth.
# V_esc = 327697.0. Mass = 4868499999999999835373568.00. Name: Venus.
# V_esc = 158831.0. Mass = 641849999999999988989952.00. Name: Mars.
# V_esc = 134416.0. Mass = 330219999999999996854272.00. Name: Mercury.
# V_esc = 75126.0. Mass = 73489999999999999475712.00. Name: Moon.
# V_esc = 37367.0. Mass = 12499999999999998951424.00. Name: Pluto.

# %%
planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }
for i in range(1):
    new = list(planetsmass.values())
print(new)
# Out:
# [0.33, 4.87, 5.98, 0.65, 1900, 570, 87, 100, 0.7]

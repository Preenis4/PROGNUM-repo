# %%
#5.2

import numpy as np
name = input('Enter name: ')
data = np.loadtxt(name, delimiter=',', )

x = data[:, 0]
y = data[:, 1]

print(np.min(x), np.max(x), np.mean(x))
y_med = np.median(y)
y2 = (y - y_med)**2
print(np.min(y), np.max(y), np.mean(y))
print(y2)
# Out:
# Enter name: sip.txt
# 0.0 87698.0 13219.0
# 0.0 9.0 4.3
# [ 6.25  2.25  0.25  6.25 20.25  2.25  6.25 20.25  0.25 20.25]

# %%
#5.6

import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = np.concatenate((a, b))
print(c, np.shape(c))
# Out:
# [1 2 3 4 5 6] (6,)

# %%
import numpy as np

a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
c = np.concatenate((a,b), axis=1)
print(c)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %%
#5.9

import imageio.v2 as imageio
import matplotlib.pyplot as plt

data = imageio.imread('m101BW.jpg')

mask = data >= 60
ndata = np.copy(data)
ndata[ndata < 60] = 0
x = np.where(data>=60, data, 0.)

plt.imshow(data, cmap='jet')
plt.contour(data, levels=np.percentile(data, [90,95,99]))
plt.show()
plt.imshow(ndata, cmap='jet')

# %%
#5.10

import numpy as np
import matplotlib.pyplot as plt

temp = np.loadtxt('ngc6946.txt')
data = temp.reshape(40, 50, 70)
z = data[:,25,35]
print(z)
zsum = 'sum:' + str(np.sum(z))
zmin = 'min: ' + str(np.min(z))
zmax = 'max: ' + str(np.max(z))
zstd = 'std: ' + str(np.std(z))
zmean = 'mean: ' + str(np.mean(z))
zx = np.arange(np.size(z))

plt.plot(zx,z)
plt.text(0, 0.06, zsum)
plt.text(0, 0.05, zmin)
plt.text(0, 0.04, zmax)
plt.text(0, 0.03, zstd)
plt.text(0, 0.02, zmean)
# Out:
# [0.00482 0.00666 0.00705 0.00889 0.01269 0.02012 0.02789 0.03712 0.03985
#  0.04617 0.0606  0.04935 0.02734 0.01746 0.0149  0.0247  0.03478 0.03472
#  0.03174 0.02931 0.02995 0.02909 0.02687 0.0247  0.02483 0.02504 0.02486
#  0.0228  0.01888 0.01625 0.01589 0.01473 0.01294 0.01236 0.01144 0.01118
#  0.01038 0.00848 0.00751 0.0072 ]
# Text(0, 0.02, 'mean: 0.0222885')

# %%
#5.11

import numpy as np
import matplotlib.pyplot as plt

temp = np.loadtxt('ngc6946.txt')
data = temp.reshape(40, 50, 70)
fplane = data[1,:,:]
fmean = np.mean(fplane)
fstd = np.std(fplane)

plt.imshow(fplane, origin='lower')
plt.colorbar()
plt.contour(fplane, levels=[fmean, fmean + fstd, fmean +2*fstd], cmap='Oranges')

# %%
#5.12

import sys
import numpy as np
from scipy.constants import c

class Galaxy:    
    """Class for redshift calculation of galaxies"""  
    caH_0 = 3968.5      # Calcium H line in rest frame
    
    def __init__(self, name, calciumHline=caH_0):
        self.name = name
        self.caH = calciumHline
        
    def redshift(self):        
        return (self.caH - self.caH_0)/self.caH
    
    def velocity(self, redshft):
        return (redshft * c)/1000
    
gar = Galaxy('mine',4000)
z = gar.redshift()

print(gar.velocity(z))
# Out:
# 2360.8656067499996

# %%
#5.13

import numpy as np
from matplotlib.pyplot import figure, show
from matplotlib.patches import Ellipse

Nx = 400
Ny = 300
data = np.random.random((Ny,Nx))

class AstroEllipse(Ellipse):
   def __init__(self, xc, yc, semi_major, semi_minor, position_angle, **args):
      assert(semi_major >= semi_minor)  # Prerequisite to make angle unambiguous
      XY = (xc, yc)                  # MPL requires center as a tuple
      angle_mpl = position_angle     # Angle for MatPlotLib's ellipse patch
      height = 2.0*semi_major        # height: is along vertical axis for an unrotated ellipse
      width  = 2.0*semi_minor        # width:  is along horizontal axis for an unrotated ellipse
      super().__init__(XY, width, height, angle=angle_mpl, **args)
    
fig = figure()
ax = fig.subplots()
ax.imshow(data, interpolation='none', origin="lower", cmap='gray')
att = AstroEllipse(200, 150, 100, 50, position_angle=30, facecolor='None', edgecolor='blue')
ax.add_patch(att)
